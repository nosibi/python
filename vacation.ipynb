# %%
import pandas as pd
data = {
    '변승민':'22-71604760',
    '구민준':'22-71002692',
    '신비':'22-71002771',
    '정재영':'22-71606431',
    '현선민':'22-71606471',
    '임규찬':'22-71606411',
    '김태훈':'22-71606292',
    '이진성':'22-71606405',
    '정민재':'22-71606427',
    '김준영':'22-76035282',
    '남성규':'22-76035383',
    '최재혁':'22-76044817',
    '강성우':'22-76036568',
    '김화평':'22-76037049',
    '이영광':'22-71606884',
    '임영준':'22-71607450',
    '정경우':'22-76060536',
    '김성수':'22-71115134',
    '김태우':'23-76002540',
    '김바다':'22-71513098',
    '유경석':'22-71513170',
    '김민석':'23-71500500',
    '최태현':'23-71500717',
    '나상혁':'23-71500539',
    '김민재':'23-76020255',
    '김성현':'23-76020299',
    '조수민':'23-71507082',
    '윤기문':'23-71506996',
    '심성보':'23-76007324',
    '이서진':'23-76039669',
    '이승민':'23-71509757',
    '정윤호':'23-71509800',
    '박재원':'23-76042662',
    '김민준':'23-76042287',
    '권태혁':'23-76042162',
    '신재욱':'22-76052265',
    '조성민':'23-76045062',
    '임동현':'23-76044898',
    '주민혁':'23-71511907',
    '장진영':'23-71511889',
}
df = pd.DataFrame(data,index = ['군번'])
df.index.name = '이름'
df.to_excel('mnumb.xlsx')

# %%
df = pd.read_excel('mnumb.xlsx')
df
