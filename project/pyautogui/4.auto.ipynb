# %%
import pyautogui
import time
import pyperclip

print(pyautogui.position())

pyautogui.moveTo(690,169,2)
pyautogui.click()
time.sleep(0.5)

pyperclip.copy("연천 날씨")
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep(2) # 바로 스크린샷으로 넘어가면 페이지가 넘어가기도 전에 캡쳐되므로 2초 시간 간격을 둔다

start_x = 381
start_y = 227
end_x = 1081
end_y = 877

pyautogui.screenshot(r"C:\Python\project\pyautogui\연천 날씨.png", region=(start_x, start_y, end_x - start_x, end_y - start_y))

#region = (시작좌표 x, 시작좌표 y, 크기 x, 크기 y)
# Out:
# Point(x=1098, y=771)
# <PIL.Image.Image image mode=RGB size=700x650>
